# %% [markdown]
# # Scraping tweets using Twitter API

# %%
#Importing necessary modules

from tweepy import OAuthHandler
import tweepy
import pandas as pd
import time
import numpy as np

# %%
#Connecting to Twitter API Essential

API_key = 'xxx'
API_key_secret = "xxx"
bearer_token = "xxxx"
access_token= 'xxx'
access_token_secret='xxx'

auth = OAuthHandler(API_key, API_key_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth)

# %%
#Defining functions to scrape tweets and embedding then into a dataframe

def printtweetdata(n, ith_tweet):
        print()
        print(f"Tweet {n}:")
        print(f"Username:{ith_tweet[0]}")
        print(f"Description:{ith_tweet[1]}")
        print(f"Location:{ith_tweet[2]}")
        print(f"Following Count:{ith_tweet[3]}")
        print(f"Follower Count:{ith_tweet[4]}")
        print(f"Total Tweets:{ith_tweet[5]}")
        print(f"Retweet Count:{ith_tweet[6]}")
        print(f"Tweet Text:{ith_tweet[7]}")
        print(f"Hashtags Used:{ith_tweet[8]}")
        
def scrape(words, date_since, numtweet):
 
        # Creating DataFrame using pandas
        db = pd.DataFrame(columns=['username',
                                   'description',
                                   'location',
                                   'following',
                                   'followers',
                                   'totaltweets',
                                   'retweetcount',
                                   'text',
                                   'hashtags'])
 
        # We are using .Cursor() to search
        # through twitter for the required tweets.
        # The number of tweets can be
        # restricted using .items(number of tweets)
        tweets = tweepy.Cursor(api.search_tweets,
                               words, lang="en",
                               since_id=date_since,
                               tweet_mode='extended').items(numtweet)
 
        list_tweets = [tweet for tweet in tweets]
        i = 1
 
        # we will iterate over each tweet in the
        # list for extracting information about each tweet
        for tweet in list_tweets:
                username = tweet.user.screen_name
                description = tweet.user.description
                location = tweet.user.location
                following = tweet.user.friends_count
                followers = tweet.user.followers_count
                totaltweets = tweet.user.statuses_count
                retweetcount = tweet.retweet_count
                hashtags = tweet.entities['hashtags']
 
                try:
                        text = tweet.retweeted_status.full_text
                except AttributeError:
                        text = tweet.full_text
                hashtext = list()
                for j in range(0, len(hashtags)):
                        hashtext.append(hashtags[j]['text'])
 
                # Here we are appending all the
                # extracted information in the DataFrame
                ith_tweet = [username, description,
                             location, following,
                             followers, totaltweets,
                             retweetcount, text, hashtext]
                db.loc[len(db)] = ith_tweet
 
                # Function call to print tweet data on screen
                printtweetdata(i, ith_tweet)
                i = i+1
        filename = 'scraped_tweets.csv'
 
        # we will save our database as a CSV file.
        db.to_csv(filename)

# %% [markdown]
# ### Quantum Computing in 2022

# %%
#Getting 100 recent posts on Quantum Computing

words = ["#quantumcomputing","#2022"]
date_since = "2022-01-01"
numtweet= 100
scrape(words,date_since,numtweet)
# Out:
# Tweet 1:
# Username:rvp
# Description:Master of Science, Electrical & Computer Engg, Carnegie Mellon 1986 | Master of Engg, Materials Science & Engg, CarnegieMellon 1985 | MS Physics IIT Kanpur 1982
# Location:New Delhi, India
# Following Count:4956
# Follower Count:4607
# Total Tweets:826978
# Retweet Count:0
# Tweet Text:Things worth reading: 4th July 2022 https://t.co/99bxwQjA13 #news #cybersecurity #infosec  https://t.co/XKR1y00kq5  #RaviVisvesvarayaSharadaPrasad #IoT #IIoT #InternetOfThings #IndustrialInternetOfThings #QuantumComputing #CloudComputing #EdgeComputing #CyberSecurity #BigDataA…
# Hashtags Used:['news', 'cybersecurity', 'infosec', 'RaviVisvesvarayaSharadaPrasad', 'IoT', 'IIoT', 'InternetOfThings', 'IndustrialInternetOfThings', 'QuantumComputing', 'CloudComputing', 'EdgeComputing', 'CyberSecurity', 'BigDataA']
#
# Tweet 2:
# Username:rvp
# Description:Master of Science, Electrical & Computer Engg, Carnegie Mellon 1986 | Master of Engg, Materials Science & Engg, CarnegieMellon 1985 | MS Physics IIT Kanpur 1982
# Location:New Delhi, India
# Following Count:4956
# Follower Count:4607
# Total Tweets:826978
# Retweet Count:0
# Tweet Text:Is the UK government prepared for its greatest threat? https://t.co/2lx8fMoGzP #news #cybersecurity #infosec https://t.co/tf6QEfforj  https://t.co/jOmSX8Sf1s  #RaviVisvesvarayaSharadaPrasad #IoT #IIoT #InternetOfThings #IndustrialInternetOfThings #QuantumComputing #CloudCompu…
# Hashtags Used:['news', 'cybersecurity', 'infosec', 'RaviVisvesvarayaSharadaPrasad', 'IoT', 'IIoT', 'InternetOfThings', 'IndustrialInternetOfThings', 'QuantumComputing', 'CloudCompu']
#
# Tweet 3:
# Username:rvp
# Description:Master of Science, Electrical & Computer Engg, Carnegie Mellon 1986 | Master of Engg, Materials Science & Engg, CarnegieMellon 1985 | MS Physics IIT Kanpur 1982
# Location:New Delhi, India
# Following Count:4956
# Follower Count:4607
# Total Tweets:826978
# Retweet Count:0
# Tweet Text:Malicious activities insiders perform in enterprise applications https://t.co/UWxuv6hwCH #news #cybersecurity #infosec https://t.co/TFYjp7W1uc  https://t.co/vGi4sccy6i  #RaviVisvesvarayaSharadaPrasad #IoT #IIoT #InternetOfThings #IndustrialInternetOfThings #QuantumComputing #…
# Hashtags Used:['news', 'cybersecurity', 'infosec', 'RaviVisvesvarayaSharadaPrasad', 'IoT', 'IIoT', 'InternetOfThings', 'IndustrialInternetOfThings', 'QuantumComputing']
#
# Tweet 4:
# Username:rvp
# Description:Master of Science, Electrical & Computer Engg, Carnegie Mellon 1986 | Master of Engg, Materials Science & Engg, CarnegieMellon 1985 | MS Physics IIT Kanpur 1982
# Location:New Delhi, India
# Following Count:4956
# Follower Count:4607
# Total Tweets:826978
# Retweet Count:0
# Tweet Text:CircleCI unveils new features to its self-hosted runners https://t.co/0CNISvkJOY #news #cybersecurity #infosec https://t.co/yPiF0wBwrZ  https://t.co/XpMsDi7mQ5  #RaviVisvesvarayaSharadaPrasad #IoT #IIoT #InternetOfThings #IndustrialInternetOfThings #QuantumComputing #CloudCom…
# Hashtags Used:['news', 'cybersecurity', 'infosec', 'RaviVisvesvarayaSharadaPrasad', 'IoT', 'IIoT', 'InternetOfThings', 'IndustrialInternetOfThings', 'QuantumComputing', 'CloudCom']
#
# Tweet 5:
# Username:rvp
# Description:Master of Science, Electrical & Computer Engg, Carnegie Mellon 1986 | Master of Engg, Materials Science & Engg, CarnegieMellon 1985 | MS Physics IIT Kanpur 1982
# Location:New Delhi, India
# Following Count:4956
# Follower Count:4607
# Total Tweets:826978
# Retweet Count:0
# Tweet Text:British Army’s Twitter and YouTube feeds hijacked by crypto-promos https://t.co/6Q5s1e6D8h #news #cybersecurity #infosec https://t.co/hMkiN5FW0h  https://t.co/kQ2grBYuxP  #RaviVisvesvarayaSharadaPrasad #IoT #IIoT #InternetOfThings #IndustrialInternetOfThings #QuantumComputing…
# Hashtags Used:['news', 'cybersecurity', 'infosec', 'RaviVisvesvarayaSharadaPrasad', 'IoT', 'IIoT', 'InternetOfThings', 'IndustrialInternetOfThings', 'QuantumComputing']
#
# Tweet 6:
# Username:rvp
# Description:Master of Science, Electrical & Computer Engg, Carnegie Mellon 1986 | Master of Engg, Materials Science & Engg, CarnegieMellon 1985 | MS Physics IIT Kanpur 1982
# Location:New Delhi, India
# Following Count:4956
# Follower Count:4607
# Total Tweets:826978
# Retweet Count:1
# Tweet Text:Eight top DevSecOps trends to support IT innovation in 2022 https://t.co/qyXgUMUeKa #news #cybersecurity #infosec https://t.co/rrRcF4uKqj  https://t.co/R4YUi9fJhF  #RaviVisvesvarayaSharadaPrasad #IoT #IIoT #InternetOfThings #IndustrialInternetOfThings #QuantumComputing #Cloud…
# Hashtags Used:['news', 'cybersecurity', 'infosec', 'RaviVisvesvarayaSharadaPrasad', 'IoT', 'IIoT', 'InternetOfThings', 'IndustrialInternetOfThings', 'QuantumComputing', 'Cloud']
#
# Tweet 7:
# Username:Tech_on_Edge
# Description:The latest news, articles and research in Artificial Intelligence, Machine Learning, DL, Blockchain, IoT, Quantum Computing, Web and Mobile technologies
# Location:
# Following Count:97
# Follower Count:118
# Total Tweets:18854
# Retweet Count:0
# Tweet Text:Most tweeted articles today in Quantum Computing:
# - NIST to Announce PQC Algorithm Selections on July 5, 2022, #QuantumComputing
# Read all new articles on: https://t.co/DhXa0z7jK4 ,
#     https://t.co/WLHMxyr2Hk
# Hashtags Used:['QuantumComputing']
#
# Tweet 8:
# Username:Tech_on_Edge
# Description:The latest news, articles and research in Artificial Intelligence, Machine Learning, DL, Blockchain, IoT, Quantum Computing, Web and Mobile technologies
# Location:
# Following Count:97
# Follower Count:118
# Total Tweets:18854
# Retweet Count:0
# Tweet Text:Most tweeted articles today in Quantum Computing:
# - Quantum Computing, Lower Construction Quality, Legal Tech Seen as Emerging Risks: Swiss Re, #QuantumComputing
# Read all new articles on: https://t.co/9Zxi644ZyJ ,
#     https://t.co/uqddrlBNeu
# Hashtags Used:['QuantumComputing']
#
# Tweet 9:
# Username:qih_apprentice
# Description:A trainee @#QIH sharing news and topics on quantum information science and technology #Quantumcomputing #QIS #QuantumTechnology Inquiries admin.qih@ml.riken.jp
# Location:Wako City, Japan
# Following Count:126
# Follower Count:73
# Total Tweets:584
# Retweet Count:0
# Tweet Text:QIH Topics　https://t.co/7i69LncEBk 4 July 2022
# Science event for school children and students "Welcome to the mysterious world of "Quantum" - First step to Quantum computer - " will be held on August 11th (Thursday) -13th (Saturday) ... #QIH #Quantumcomputing #量子 #Quantum
# Hashtags Used:['QIH', 'Quantumcomputing', '量子', 'Quantum']
#
# Tweet 10:
# Username:peterjmsimons
# Description:Executing industrial strategies in
# Media, Telco, Internet, Mobile, Tech.
# Location:Europe
# Following Count:942
# Follower Count:900
# Total Tweets:42428
# Retweet Count:10
# Tweet Text:Where Next for #QuantumComputing  and Cybersecurity?
# #ThreatIntel #Phishing #ransomware #cyberattacks #privacy #cyberintelligence #cybercriminals #scams #infosec #cybersec #cybersecurity #SocialEngineering
# https://t.co/gZYLrb6CVP #cyberintelligence #feedly
# Hashtags Used:['QuantumComputing', 'ThreatIntel', 'Phishing', 'ransomware', 'cyberattacks', 'privacy']
#
# Tweet 11:
# Username:MJBiercuk
# Description:Founder @qctrlhq making #quantum tech useful for you. Professor. Speaker. @fondationgphg Academy member. Unabashed supporter of constitutional democracy.
# Location:Sydney, New South Wales
# Following Count:1672
# Follower Count:7678
# Total Tweets:28759
# Retweet Count:1
# Tweet Text:Building on our last announcement in April, we are at the stage of developing and demonstrating the full quantum technology stack to obtain solutions for a high-value transport problem with #QuantumComputing
#
# https://t.co/QPqK1yIgFu https://t.co/ArRPXObUZV
# Hashtags Used:[]
#
# Tweet 12:
# Username:CyberDFIR
# Description:
# Location:
# Following Count:25
# Follower Count:750
# Total Tweets:187584
# Retweet Count:10
# Tweet Text:Where Next for #QuantumComputing  and Cybersecurity?
# #ThreatIntel #Phishing #ransomware #cyberattacks #privacy #cyberintelligence #cybercriminals #scams #infosec #cybersec #cybersecurity #SocialEngineering
# https://t.co/gZYLrb6CVP #cyberintelligence #feedly
# Hashtags Used:['QuantumComputing', 'ThreatIntel', 'Phishing', 'ransomware', 'cyberattacks', 'privacy']
#
# Tweet 13:
# Username:AiSpirits_Inc
# Description:
# Location:
# Following Count:598
# Follower Count:95
# Total Tweets:4072
# Retweet Count:0
# Tweet Text:Advocating a new paradigm for electron simulations
# Although most fundamental mathematical equations that describe electronic structures are long known, they are too complex to be solved in practice.
# https://t.co/x9rarAHexs　#QuantumComputing
# Hashtags Used:['QuantumComputing']
#
# Tweet 14:
# Username:qih_apprentice
# Description:A trainee @#QIH sharing news and topics on quantum information science and technology #Quantumcomputing #QIS #QuantumTechnology Inquiries admin.qih@ml.riken.jp
# Location:Wako City, Japan
# Following Count:126
# Follower Count:73
# Total Tweets:584
# Retweet Count:0
# Tweet Text:QIH Topics  https://t.co/7i69LncEBk 4 June 2022
# A roundtable discussion and research facility tour for female students will be held on Thursday, September 1st.(in Japanese)　RIKEN RQC
# https://t.co/CX1i1S3t8x #QIH #Quantumcomputing #量子 #Quantum
# Hashtags Used:['QIH', 'Quantumcomputing', '量子', 'Quantum']
#
# Tweet 15:
# Username:qctrlHQ
# Description:Make quantum technology useful. Advanced, intuitive and scalable quantum control engineering solutions. Subscribe to our YouTube channel: https://t.co/UnlUZ1qpW0
# Location:Sydney, New South Wales
# Following Count:41
# Follower Count:4718
# Total Tweets:770
# Retweet Count:1
# Tweet Text:Building on our last announcement in April, we are at the stage of developing and demonstrating the full quantum technology stack to obtain solutions for a high-value transport problem with #QuantumComputing
#
# https://t.co/QPqK1yIgFu https://t.co/ArRPXObUZV
# Hashtags Used:['QuantumComputing']
#
# Tweet 16:
# Username:FreedomGeopol
# Description:I am waiting for the cancelation Gulag by commie Twitter. Putting me on a list means block.
# Location:
# Following Count:203
# Follower Count:1668
# Total Tweets:61124
# Retweet Count:3
# Tweet Text:World's first quantum computer integrated circuit
#
# "The ability to observe precisely how molecules function at the atomic scale would remove a lot of the guesswork in the creation of new materials."
#
# ▶️ Read more https://t.co/iUNnEn0IHX #QuantumComputing #quantumcomputer #quantum
# Hashtags Used:[]
#
# Tweet 17:
# Username:bjavadi
# Description:Associate Professor in Cloud Computing and Networking at Western Sydney University
# Location:Sydney, New South Wales
# Following Count:431
# Follower Count:190
# Total Tweets:250
# Retweet Count:0
# Tweet Text:The IEEE Technical Committee on Cloud Computing (TCCLD) Webinar, July 11, 2022 at 12pm CET (Online Free Event)
# Presenters: @omerfrana, Marcus Doherty
# Topics: #distributedcomputing  #edgecomputing,  #quantumcomputing
# Registration: https://t.co/rFJJpePvmd https://t.co/nhd3Z1k0ax
# Hashtags Used:['distributedcomputing', 'edgecomputing', 'quantumcomputing']
#
# Tweet 18:
# Username:unahub
# Description:The new paradigm internet combines #AI #blockchain #quantum into a smart, all in one platform for mass adoption. #mergers #BTC #ether #crypto #tokensale
# Location:
# Following Count:832
# Follower Count:1554
# Total Tweets:88634
# Retweet Count:3
# Tweet Text:World's first quantum computer integrated circuit
#
# "The ability to observe precisely how molecules function at the atomic scale would remove a lot of the guesswork in the creation of new materials."
#
# ▶️ Read more https://t.co/iUNnEn0IHX #QuantumComputing #quantumcomputer #quantum
# Hashtags Used:[]
#
# Tweet 19:
# Username:cybsecbot
# Description:I am a bot. Follow me if you want to know more about #cybersecurity #malware #databreach #hacking #threatintel #osint #0day #APT Made with ♥️ by @daphiel
# Location:Unknown
# Following Count:1
# Follower Count:2445
# Total Tweets:105755
# Retweet Count:10
# Tweet Text:Where Next for #QuantumComputing  and Cybersecurity?
# #ThreatIntel #Phishing #ransomware #cyberattacks #privacy #cyberintelligence #cybercriminals #scams #infosec #cybersec #cybersecurity #SocialEngineering
# https://t.co/gZYLrb6CVP #cyberintelligence #feedly
# Hashtags Used:['QuantumComputing', 'ThreatIntel', 'Phishing', 'ransomware', 'cyberattacks', 'privacy']
#
# Tweet 20:
# Username:beefyspace
# Description:Part bot, part not - I would love to change the world, but they wouldn't give me the source code
# Location:Neither here nor there
# Following Count:388
# Follower Count:1557
# Total Tweets:161115
# Retweet Count:10
# Tweet Text:Where Next for #QuantumComputing  and Cybersecurity?
# #ThreatIntel #Phishing #ransomware #cyberattacks #privacy #cyberintelligence #cybercriminals #scams #infosec #cybersec #cybersecurity #SocialEngineering
# https://t.co/gZYLrb6CVP #cyberintelligence #feedly
# Hashtags Used:['QuantumComputing', 'ThreatIntel', 'Phishing', 'ransomware', 'cyberattacks', 'privacy']
#
# Tweet 21:
# Username:sectest9
# Description:News Hub! Get the latest Security News & Updates!
# Location:Hyderabad, India
# Following Count:1
# Follower Count:41270
# Total Tweets:2798897
# Retweet Count:10
# Tweet Text:Where Next for #QuantumComputing  and Cybersecurity?
# #ThreatIntel #Phishing #ransomware #cyberattacks #privacy #cyberintelligence #cybercriminals #scams #infosec #cybersec #cybersecurity #SocialEngineering
# https://t.co/gZYLrb6CVP #cyberintelligence #feedly
# Hashtags Used:['QuantumComputing', 'ThreatIntel', 'Phishing', 'ransomware', 'cyberattacks', 'privacy']
#
# Tweet 22:
# Username:CyberSecurityN8
# Description:The place for InfoSec, CyberSecurity, DevSecOps, DataSecurity and many more!!! Stay tuned.
# Location:
# Following Count:2
# Follower Count:28591
# Total Tweets:1297866
# Retweet Count:10
# Tweet Text:Where Next for #QuantumComputing  and Cybersecurity?
# #ThreatIntel #Phishing #ransomware #cyberattacks #privacy #cyberintelligence #cybercriminals #scams #infosec #cybersec #cybersecurity #SocialEngineering
# https://t.co/gZYLrb6CVP #cyberintelligence #feedly
# Hashtags Used:['QuantumComputing', 'ThreatIntel', 'Phishing', 'ransomware', 'cyberattacks', 'privacy']
#
# Tweet 23:
# Username:SecurityXTV
# Description:News, training, jobs, tenders & marketplace for security related needs. #cyber #security #CSuite #risk #digital #IoT #fire #CCTV #facilitiesmanagement #tech
# Location:England, United Kingdom
# Following Count:5001
# Follower Count:4422
# Total Tweets:80275
# Retweet Count:10
# Tweet Text:Where Next for #QuantumComputing  and Cybersecurity?
# #ThreatIntel #Phishing #ransomware #cyberattacks #privacy #cyberintelligence #cybercriminals #scams #infosec #cybersec #cybersecurity #SocialEngineering
# https://t.co/gZYLrb6CVP #cyberintelligence #feedly
# Hashtags Used:['QuantumComputing', 'ThreatIntel', 'Phishing', 'ransomware', 'cyberattacks', 'privacy']
#
# Tweet 24:
# Username:javier_carriazo
# Description:
# Location:
# Following Count:229
# Follower Count:486
# Total Tweets:23402
# Retweet Count:10
# Tweet Text:Where Next for #QuantumComputing  and Cybersecurity?
# #ThreatIntel #Phishing #ransomware #cyberattacks #privacy #cyberintelligence #cybercriminals #scams #infosec #cybersec #cybersecurity #SocialEngineering
# https://t.co/gZYLrb6CVP #cyberintelligence #feedly
# Hashtags Used:['QuantumComputing', 'ThreatIntel', 'Phishing', 'ransomware', 'cyberattacks', 'privacy']
#
# Tweet 25:
# Username:future_timeline
# Description:Future predictions, trends and forecasts – from the near future, to the far future and beyond. The official Twitter page for https://t.co/FamLCzAg8C
# Location:The Future
# Following Count:669
# Follower Count:10158
# Total Tweets:24845
# Retweet Count:3
# Tweet Text:World's first quantum computer integrated circuit
#
# "The ability to observe precisely how molecules function at the atomic scale would remove a lot of the guesswork in the creation of new materials."
#
# ▶️ Read more https://t.co/iUNnEn0IHX #QuantumComputing #quantumcomputer #quantum
# Hashtags Used:['QuantumComputing', 'quantumcomputer', 'quantum']
#
# Tweet 26:
# Username:javier_carriazo
# Description:
# Location:
# Following Count:229
# Follower Count:486
# Total Tweets:23402
# Retweet Count:10
# Tweet Text:Where Next for #QuantumComputing  and Cybersecurity?
# #ThreatIntel #Phishing #ransomware #cyberattacks #privacy #cyberintelligence #cybercriminals #scams #infosec #cybersec #cybersecurity #SocialEngineering
# https://t.co/gZYLrb6CVP #cyberintelligence #feedly
# Hashtags Used:['QuantumComputing', 'ThreatIntel', 'Phishing', 'ransomware', 'cyberattacks', 'privacy', 'cyberintelligence', 'cybercriminals', 'scams', 'infosec', 'cybersec', 'cybersecurity', 'SocialEngineering', 'cyberintelligence', 'feedly']
#
# Tweet 27:
# Username:education_24x7
# Description:All education content. Education changes the life.
# Software Developer| ML | DS | Technical Blogging at https://t.co/WNErKjwYtH |
# Location:Delhi
# Following Count:7
# Follower Count:7604
# Total Tweets:646168
# Retweet Count:2
# Tweet Text:Singapore ups investment in #QuantumComputing to stay ahead of security threats
# 31 May, 2022 07:00:00
#
# @arXiv_Daily @machinelearnflx @CurieuxExplorer @nigewillson @SpirosMargaris @DrJDrooghaag
#
# #quantum #singapore #encryption #engineering
#
# https://t.co/CWKgKwrRt4
# Hashtags Used:['QuantumComputing']
# Tweet 28:
# Username:zeekayinfo3
# Description:Analyst/blogger focusing on several areas, including AI and quantum computing, & and any related areas. https://t.co/Epq06pmqX5
# Location:Silicon Valley
# Following Count:4224
# Follower Count:2039
# Total Tweets:27169
# Retweet Count:4
# Tweet Text:The key to quantum computing AI applications: Flexible programming languages
# When enabled by flexible AI programming languages, quantum computing performs AI calculations much faster, and at a greater scale.
# https://t.co/KnSQEcklMc　#QuantumComputing
# Hashtags Used:[]
#
# Tweet 29:
# Username:zeekayinfo3
# Description:Analyst/blogger focusing on several areas, including AI and quantum computing, & and any related areas. https://t.co/Epq06pmqX5
# Location:Silicon Valley
# Following Count:4224
# Follower Count:2039
# Total Tweets:27169
# Retweet Count:2
# Tweet Text:NIST to Announce PQC Algorithm Selections on July 5, 2022
# https://t.co/7jaM2mGo5i　#QuantumComputing
# Hashtags Used:['QuantumComputing']
#
# Tweet 30:
# Username:zeekayinfo3
# Description:Analyst/blogger focusing on several areas, including AI and quantum computing, & and any related areas. https://t.co/Epq06pmqX5
# Location:Silicon Valley
# Following Count:4224
# Follower Count:2039
# Total Tweets:27169
# Retweet Count:2
# Tweet Text:Research Roundup for June 2022
# https://t.co/IkqGsmJHAh #QuantumComputing
# Hashtags Used:['QuantumComputing']
#
# Tweet 31:
# Username:zeekayinfo3
# Description:Analyst/blogger focusing on several areas, including AI and quantum computing, & and any related areas. https://t.co/Epq06pmqX5
# Location:Silicon Valley
# Following Count:4224
# Follower Count:2039
# Total Tweets:27169
# Retweet Count:2
# Tweet Text:Tech Trends: What Will Be The Biggest Innovations by 2022
# https://t.co/t0UvTtHTAJ　#QuantumComputing
# Hashtags Used:['QuantumComputing']
#
# Tweet 32:
# Username:ICTandEnergy
# Description:ICT屋、元電気屋、ICTと電力の融合　＝＞　スマートグリッド
# Location:シリコンバレーの某所
# Following Count:860
# Follower Count:190
# Total Tweets:14415
# Retweet Count:4
# Tweet Text:The key to quantum computing AI applications: Flexible programming languages
# When enabled by flexible AI programming languages, quantum computing performs AI calculations much faster, and at a greater scale.
# https://t.co/KnSQEcklMc　#QuantumComputing
# Hashtags Used:[]
#
# Tweet 33:
# Username:ICTandEnergy
# Description:ICT屋、元電気屋、ICTと電力の融合　＝＞　スマートグリッド
# Location:シリコンバレーの某所
# Following Count:860
# Follower Count:190
# Total Tweets:14415
# Retweet Count:2
# Tweet Text:NIST to Announce PQC Algorithm Selections on July 5, 2022
# https://t.co/7jaM2mGo5i　#QuantumComputing
# Hashtags Used:['QuantumComputing']
#
# Tweet 34:
# Username:ICTandEnergy
# Description:ICT屋、元電気屋、ICTと電力の融合　＝＞　スマートグリッド
# Location:シリコンバレーの某所
# Following Count:860
# Follower Count:190
# Total Tweets:14415
# Retweet Count:2
# Tweet Text:Tech Trends: What Will Be The Biggest Innovations by 2022
# https://t.co/t0UvTtHTAJ　#QuantumComputing
# Hashtags Used:['QuantumComputing']
#
# Tweet 35:
# Username:ICTandEnergy
# Description:ICT屋、元電気屋、ICTと電力の融合　＝＞　スマートグリッド
# Location:シリコンバレーの某所
# Following Count:860
# Follower Count:190
# Total Tweets:14415
# Retweet Count:2
# Tweet Text:Research Roundup for June 2022
# https://t.co/IkqGsmJHAh #QuantumComputing
# Hashtags Used:['QuantumComputing']
#
# Tweet 36:
# Username:AndyHorvitz
# Description:Dad. Skier. Entrepreneur. Innovator. Foodie. Digital transformations at https://t.co/dNuIA7cL0f #BigData #MachineLearning #AI and more.
# Location:Massachusetts
# Following Count:4500
# Follower Count:1636
# Total Tweets:58830
# Retweet Count:8
# Tweet Text:A new language for #QuantumComputing
#
# https://t.co/salHDqaoTx @MIT @MIT_CSAIL
#
# #Coding #100DaysOfCode
# Cc @DeepLearn007 @rwang0 @sandy_carter https://t.co/O2Bo5RxZr6
# Hashtags Used:['QuantumComputing', 'Coding', '100DaysOfCode']
#
# Tweet 37:
# Username:SimplifiedIct
# Description:Daily technical news , technical memes , history about computer world |
# Follow for daily #facts #quotes #blogs about #tech #programming #coding #computers
# Location:Guwahati, India
# Following Count:3
# Follower Count:505
# Total Tweets:41669
# Retweet Count:8
# Tweet Text:A new language for #QuantumComputing
#
# https://t.co/salHDqaoTx @MIT @MIT_CSAIL
#
# #Coding #100DaysOfCode
# Cc @DeepLearn007 @rwang0 @sandy_carter https://t.co/O2Bo5RxZr6
# Hashtags Used:['QuantumComputing', 'Coding', '100DaysOfCode']
#
# Tweet 38:
# Username:nod3bot
# Description:Built by @prmkum4r using ♥️ + nodejs, re/tweets on #javascript, #nodej and #100DaysOfCode 👋🏼
# Location:Chennai, India
# Following Count:0
# Follower Count:220
# Total Tweets:66684
# Retweet Count:8
# Tweet Text:A new language for #QuantumComputing
#
# https://t.co/salHDqaoTx @MIT @MIT_CSAIL
#
# #Coding #100DaysOfCode
# Cc @DeepLearn007 @rwang0 @sandy_carter https://t.co/O2Bo5RxZr6
# Hashtags Used:['QuantumComputing', 'Coding', '100DaysOfCode']
#
# Tweet 39:
# Username:nod3bot
# Description:Built by @prmkum4r using ♥️ + nodejs, re/tweets on #javascript, #nodej and #100DaysOfCode 👋🏼
# Location:Chennai, India
# Following Count:0
# Follower Count:220
# Total Tweets:66684
# Retweet Count:8
# Tweet Text:A new language for #QuantumComputing
#
# https://t.co/salHDqaoTx @MIT @MIT_CSAIL
#
# #Coding #100DaysOfCode
# Cc @DeepLearn007 @rwang0 @sandy_carter https://t.co/O2Bo5RxZr6
# Hashtags Used:['QuantumComputing', 'Coding', '100DaysOfCode']
#
# Tweet 40:
# Username:nod3bot
# Description:Built by @prmkum4r using ♥️ + nodejs, re/tweets on #javascript, #nodej and #100DaysOfCode 👋🏼
# Location:Chennai, India
# Following Count:0
# Follower Count:220
# Total Tweets:66684
# Retweet Count:8
# Tweet Text:A new language for #QuantumComputing
#
# https://t.co/salHDqaoTx @MIT @MIT_CSAIL
#
# #Coding #100DaysOfCode
# Cc @DeepLearn007 @rwang0 @sandy_carter https://t.co/O2Bo5RxZr6
# Hashtags Used:['QuantumComputing', 'Coding', '100DaysOfCode']
#
# Tweet 41:
# Username:xaelbot
# Description:A bot, I like and retweet on #100DaysOfCode. Block if don't want to be retweeted.
# Location:Earth
# Following Count:7
# Follower Count:6546
# Total Tweets:1739930
# Retweet Count:8
# Tweet Text:A new language for #QuantumComputing
#
# https://t.co/salHDqaoTx @MIT @MIT_CSAIL
#
# #Coding #100DaysOfCode
# Cc @DeepLearn007 @rwang0 @sandy_carter https://t.co/O2Bo5RxZr6
# Hashtags Used:['QuantumComputing', 'Coding', '100DaysOfCode']
#
# Tweet 42:
# Username:DariuszKlimows1
# Description:CEO MIO, DPO. IoT, IIoT, Compliance, ISMS (ISO 20K, 27K, 31K, GDPR, cybersecurity), KRI, ISO 9K, 14K, 45K, FSC, KZR-INIG, CAF, EFQM, NIST...
# Location:Elbląg, Polska
# Following Count:1425
# Follower Count:949
# Total Tweets:1774
# Retweet Count:8
# Tweet Text:A new language for #QuantumComputing
#
# https://t.co/salHDqaoTx @MIT @MIT_CSAIL
#
# #Coding #100DaysOfCode
# Cc @DeepLearn007 @rwang0 @sandy_carter https://t.co/O2Bo5RxZr6
# Hashtags Used:['QuantumComputing', 'Coding', '100DaysOfCode']
#
# Tweet 43:
# Username:BotKoshur
# Description:I RT #100DaysOfCode currently .
# Made with #nodejs and #twit.
# created by @__junaidshah
#
# Support me by Buying me a coffee(https://t.co/2OgKj8iqga)
# Location:
# Following Count:1
# Follower Count:611
# Total Tweets:61924
# Retweet Count:8
# Tweet Text:A new language for #QuantumComputing
#
# https://t.co/salHDqaoTx @MIT @MIT_CSAIL
#
# #Coding #100DaysOfCode
# Cc @DeepLearn007 @rwang0 @sandy_carter https://t.co/O2Bo5RxZr6
# Hashtags Used:['QuantumComputing', 'Coding', '100DaysOfCode']
#
# Tweet 44:
# Username:ipfconline1
# Description:Digital Transformation Consulting
# #AI #MachineLearning #DeepLearning
# #DataScience #AIEthics
# #EdgeComputing #Fintech
# #DigitalMarketing
# Location:Marseille, France
# Following Count:111711
# Follower Count:124684
# Total Tweets:212952
# Retweet Count:8
# Tweet Text:A new language for #QuantumComputing
#
# https://t.co/salHDqaoTx @MIT @MIT_CSAIL
#
# #Coding #100DaysOfCode
# Cc @DeepLearn007 @rwang0 @sandy_carter https://t.co/O2Bo5RxZr6
# Hashtags Used:['QuantumComputing', 'Coding', '100DaysOfCode']
#
# Tweet 45:
# Username:dbdanieljnr
# Description:Quantum Physicist||
# Quantum Software Engineer||
# QML Researcher||
# Co-founder @tech_niverse
# |Quantum Educator @Quantumics_net
#
# |PresidentNig lead @onequantumworld
# Location:Hilbert Space!
# Following Count:1769
# Follower Count:370
# Total Tweets:4696
# Retweet Count:7
# Tweet Text:🖥️   We identified 5 startups set to disrupt quantum computing in 2022.
#
# Can any of them affect your business? Find out 👉 https://t.co/irgSX5TXgT
#
# ft. @quantastica @qilimanjaro @QuantumBrillia1 @ClassiqTech
#
# #QuantumComputing #Innovation #Startups
# Hashtags Used:[]
#
# Tweet 46:
# Username:dbdanieljnr
# Description:Quantum Physicist||
# Quantum Software Engineer||
# QML Researcher||
# Co-founder @tech_niverse
# |Quantum Educator @Quantumics_net
#
# |PresidentNig lead @onequantumworld
# Location:Hilbert Space!
# Following Count:1769
# Follower Count:370
# Total Tweets:4696
# Retweet Count:11
# Tweet Text:35 of The Top Tools For Quantum Computing in 2022 💥
#
# Read here👉
# https://t.co/LqnqOgY8xa
#
# #quantumtools #quantumtechnology #quantumcomputing #quamtuminsider https://t.co/t5QCYKX4JD
# Hashtags Used:['quantumtools']
#
# Tweet 47:
# Username:beefyspace
# Description:Part bot, part not - I would love to change the world, but they wouldn't give me the source code
# Location:Neither here nor there
# Following Count:388
# Follower Count:1557
# Total Tweets:161115
# Retweet Count:1
# Tweet Text:RT @DeepFriedCyber: What is the global, digital currency? https://t.co/B9f2orxSEb #news #cybersecurity #infosec https://t.co/UN622MwBdi  https://t.co/ZCkjDDBYhM  #RaviVisvesvarayaSharadaPrasad #IoT #IIoT #InternetOfThings #IndustrialInternetOfThings #QuantumComputing #CloudCo…
# Hashtags Used:['news', 'cybersecurity', 'infosec']
#
# Tweet 48:
# Username:rvp
# Description:Master of Science, Electrical & Computer Engg, Carnegie Mellon 1986 | Master of Engg, Materials Science & Engg, CarnegieMellon 1985 | MS Physics IIT Kanpur 1982
# Location:New Delhi, India
# Following Count:4956
# Follower Count:4607
# Total Tweets:826978
# Retweet Count:1
# Tweet Text:RT @DeepFriedCyber: What is the global, digital currency? https://t.co/B9f2orxSEb #news #cybersecurity #infosec https://t.co/UN622MwBdi  https://t.co/ZCkjDDBYhM  #RaviVisvesvarayaSharadaPrasad #IoT #IIoT #InternetOfThings #IndustrialInternetOfThings #QuantumComputing #CloudCo…
# Hashtags Used:['news', 'cybersecurity', 'infosec', 'RaviVisvesvarayaSharadaPrasad', 'IoT', 'IIoT', 'InternetOfThings', 'IndustrialInternetOfThings', 'QuantumComputing', 'CloudCo']
#
# Tweet 49:
# Username:rvp
# Description:Master of Science, Electrical & Computer Engg, Carnegie Mellon 1986 | Master of Engg, Materials Science & Engg, CarnegieMellon 1985 | MS Physics IIT Kanpur 1982
# Location:New Delhi, India
# Following Count:4956
# Follower Count:4607
# Total Tweets:826978
# Retweet Count:0
# Tweet Text:RT @DeepFriedCyber: Things worth reading: 28th June 2022 https://t.co/TQwCAmLwsr #news #cybersecurity #infosec  https://t.co/DlHTcmk9jy  #RaviVisvesvarayaSharadaPrasad #IoT #IIoT #InternetOfThings #IndustrialInternetOfThings #QuantumComputing #CloudComputing #EdgeComputing #Cy…
# Hashtags Used:['news', 'cybersecurity', 'infosec', 'RaviVisvesvarayaSharadaPrasad', 'IoT', 'IIoT', 'InternetOfThings', 'IndustrialInternetOfThings', 'QuantumComputing', 'CloudComputing', 'EdgeComputing', 'Cy']
#
# Tweet 50:
# Username:rvp
# Description:Master of Science, Electrical & Computer Engg, Carnegie Mellon 1986 | Master of Engg, Materials Science & Engg, CarnegieMellon 1985 | MS Physics IIT Kanpur 1982
# Location:New Delhi, India
# Following Count:4956
# Follower Count:4607
# Total Tweets:826978
# Retweet Count:0
# Tweet Text:The Finanser’s Week: 27th June 2022 – 3rd July 2022 https://t.co/J4NyUHmedh #news #cybersecurity #infosec https://t.co/c6gudvPis4  https://t.co/sDg6DZlPts  #RaviVisvesvarayaSharadaPrasad #IoT #IIoT #InternetOfThings #IndustrialInternetOfThings #QuantumComputing #CloudComputin…
# Hashtags Used:['news', 'cybersecurity', 'infosec', 'RaviVisvesvarayaSharadaPrasad', 'IoT', 'IIoT', 'InternetOfThings', 'IndustrialInternetOfThings', 'QuantumComputing', 'CloudComputin']
#
# Tweet 51:
# Username:rvp
# Description:Master of Science, Electrical & Computer Engg, Carnegie Mellon 1986 | Master of Engg, Materials Science & Engg, CarnegieMellon 1985 | MS Physics IIT Kanpur 1982
# Location:New Delhi, India
# Following Count:4956
# Follower Count:4607
# Total Tweets:826978
# Retweet Count:0
# Tweet Text:RT @DeepFriedCyber: Hexagon appoints Paolo Guglielmini as CEO https://t.co/8kh3DIGS0G #news #cybersecurity #infosec https://t.co/p3hWZepZdZ  https://t.co/2cQH15yvgV  #RaviVisvesvarayaSharadaPrasad #IoT #IIoT #InternetOfThings #IndustrialInternetOfThings #QuantumComputing #Clo…
# Hashtags Used:['news', 'cybersecurity', 'infosec', 'RaviVisvesvarayaSharadaPrasad', 'IoT', 'IIoT', 'InternetOfThings', 'IndustrialInternetOfThings', 'QuantumComputing', 'Clo']
#
# Tweet 52:
# Username:Madhvendrax
# Description:I love App Development
# Location:Aligarh, India
# Following Count:224
# Follower Count:189
# Total Tweets:17886
# Retweet Count:34
# Tweet Text:Better Quantum Tunneling Interface : Courtesy #ML ▶️
# #Analytics #BigData #AI #Python #Rstats #Reactjs #IoT #IIoT #Serverless #flutter #TensorFlow
# #javascript #MachineLearning
# #Cloud #QuantumComputing #futureofwork #programming
# #Coding #100DaysOfCode
# https://t.co/WsuTuHmR4b https://t.co/LApiNOTN2M
# Hashtags Used:['ML', 'Analytics', 'BigData', 'AI', 'Python', 'Rstats', 'Reactjs', 'IoT', 'IIoT']
# Tweet 53:
# Username:Analytics_699
# Description:Healthcare Head | Chief Mentor - XPROB |
# Top 🔟 #EmergingTech #Influencer -
# #AI #ML #IoT #Cloud #SelfDrivingCars #AR | Top 10 #Influencer #CES2022 #CES2021
# Location:
# Following Count:7207
# Follower Count:10744
# Total Tweets:30236
# Retweet Count:34
# Tweet Text:Better Quantum Tunneling Interface : Courtesy #ML ▶️
# #Analytics #BigData #AI #Python #Rstats #Reactjs #IoT #IIoT #Serverless #flutter #TensorFlow
# #javascript #MachineLearning
# #Cloud #QuantumComputing #futureofwork #programming
# #Coding #100DaysOfCode
# https://t.co/WsuTuHmR4b https://t.co/LApiNOTN2M
# Hashtags Used:['ML', 'Analytics', 'BigData', 'AI', 'Python', 'Rstats', 'Reactjs', 'IoT', 'IIoT']
#
# Tweet 54:
# Username:GroveVentures
# Description:Grove Ventures is a leading VC fund. We partner early with exceptional Israeli entrepreneurs who believe that the Deep Future is now & are ready to build it.
# Location:Tel Aviv, Israel
# Following Count:1054
# Follower Count:485
# Total Tweets:339
# Retweet Count:0
# Tweet Text:💥@GroveVentures’ NEW PORTFOLIO COMPANY Quantum Source Labs Ltd is coming out of stealth with a $15 million Seed round in this incredible cover story for The Marker (Hebrew)!
# https://t.co/yPSM4X5SuB
# #QuantumComputing #Startups #Deep_Future
# Hashtags Used:['QuantumComputing', 'Startups', 'Deep_Future']
#
# Tweet 55:
# Username:jayeshmthakur
# Description:Husband, Father, Student, Security n00b. Interested in Cyber Security Research, Pen testing, RED Teaming, & Threat Hunting, Thoughts and Tweets are my own.
# Location:::1
# Following Count:788
# Follower Count:3008
# Total Tweets:221319
# Retweet Count:13
# Tweet Text:The key to #quantumcomputing #AI applications:
#
# Flexible programming languages
#
# https://t.co/rZJYLjNTaf #fintech #ArtificialIntelligence #MachineLearning #DeepLearning #BigData @Franzinc @VentureBeat https://t.co/8x3xn5DOFk
# Hashtags Used:['quantumcomputing', 'AI', 'fintech']
#
# Tweet 56:
# Username:Max_Lyashko
# Description:VP @ICS_ERP. I share news on #IoT, #DigitalTransformation, #AI, #MachineLearning, #AR & #ERP. Follow me to track the latest trends! https://t.co/pIiMg1nQzm
# Location:
# Following Count:538
# Follower Count:1778
# Total Tweets:90394
# Retweet Count:13
# Tweet Text:The key to #quantumcomputing #AI applications:
#
# Flexible programming languages
#
# https://t.co/rZJYLjNTaf #fintech #ArtificialIntelligence #MachineLearning #DeepLearning #BigData @Franzinc @VentureBeat https://t.co/8x3xn5DOFk
# Hashtags Used:['quantumcomputing', 'AI', 'fintech']
#
# Tweet 57:
# Username:AdventChild_BTC
# Description:im 18+ not 8. not investment advice. #rt of information, sometimes i own related #stocks #otc #forex #fintech #spacetech #privateequity #OOTT #natgas📈$IMPP
# Location:Midgar Edge
# Following Count:4990
# Follower Count:1101
# Total Tweets:55805
# Retweet Count:2
# Tweet Text:The convergence of #QuantumComputing, #AI and #ProgrammingLanguages into a single computational environment could have widespread benefits. Discover how #businesses are already capitalizing on this growing development: https://t.co/Qx8Suh28uI
# Hashtags Used:['QuantumComputing', 'AI', 'ProgrammingLanguages']
#
# Tweet 58:
# Username:AdventChild_BTC
# Description:im 18+ not 8. not investment advice. #rt of information, sometimes i own related #stocks #otc #forex #fintech #spacetech #privateequity #OOTT #natgas📈$IMPP
# Location:Midgar Edge
# Following Count:4990
# Follower Count:1101
# Total Tweets:55805
# Retweet Count:4
# Tweet Text:The key to quantum computing AI applications: Flexible programming languages
# When enabled by flexible AI programming languages, quantum computing performs AI calculations much faster, and at a greater scale.
# https://t.co/KnSQEcklMc　#QuantumComputing
# Hashtags Used:[]
#
# Tweet 59:
# Username:AdventChild_BTC
# Description:im 18+ not 8. not investment advice. #rt of information, sometimes i own related #stocks #otc #forex #fintech #spacetech #privateequity #OOTT #natgas📈$IMPP
# Location:Midgar Edge
# Following Count:4990
# Follower Count:1101
# Total Tweets:55805
# Retweet Count:13
# Tweet Text:The key to #quantumcomputing #AI applications:
#
# Flexible programming languages
#
# https://t.co/rZJYLjNTaf #fintech #ArtificialIntelligence #MachineLearning #DeepLearning #BigData @Franzinc @VentureBeat https://t.co/8x3xn5DOFk
# Hashtags Used:['quantumcomputing', 'AI', 'fintech']
#
# Tweet 60:
# Username:SpirosMargaris
# Description:#VC | No. 1 #Fintech @Refinitiv & @Onalytica | @TEDx | @natechsa @ai_mediastalker @GenTwoAG @TradeFlowCrypto @CoreLedger @SparkLabsGlobal @HeradoHQ @ablrco
# Location:All Over the World
# Following Count:19661
# Follower Count:123336
# Total Tweets:259611
# Retweet Count:13
# Tweet Text:The key to #quantumcomputing #AI applications:
#
# Flexible programming languages
#
# https://t.co/rZJYLjNTaf #fintech #ArtificialIntelligence #MachineLearning #DeepLearning #BigData @Franzinc @VentureBeat https://t.co/8x3xn5DOFk
# Hashtags Used:['quantumcomputing', 'AI', 'fintech']
#
# Tweet 61:
# Username:Anantasak
# Description:BigData, Cloud, SAAS , PAAS , IoT & Blockchain
# Location:Bangkok
# Following Count:2230
# Follower Count:2473
# Total Tweets:41324
# Retweet Count:13
# Tweet Text:The key to #quantumcomputing #AI applications:
#
# Flexible programming languages
#
# https://t.co/rZJYLjNTaf #fintech #ArtificialIntelligence #MachineLearning #DeepLearning #BigData @Franzinc @VentureBeat https://t.co/8x3xn5DOFk
# Hashtags Used:['quantumcomputing', 'AI', 'fintech']
#
# Tweet 62:
# Username:SimplifiedIct
# Description:Daily technical news , technical memes , history about computer world |
# Follow for daily #facts #quotes #blogs about #tech #programming #coding #computers
# Location:Guwahati, India
# Following Count:3
# Follower Count:505
# Total Tweets:41669
# Retweet Count:4
# Tweet Text:The key to quantum computing AI applications: Flexible programming languages
# When enabled by flexible AI programming languages, quantum computing performs AI calculations much faster, and at a greater scale.
# https://t.co/KnSQEcklMc　#QuantumComputing
# Hashtags Used:[]
#
# Tweet 63:
# Username:joemckendrick
# Description:Pondering disruption, tech & otherwise, with both optimism & skepticism. Analyst/contributor: Forbes, ZDNet, Information Today, RTInsights. Army brat.
# Location:Northeast USA
# Following Count:6953
# Follower Count:14957
# Total Tweets:34558
# Retweet Count:13
# Tweet Text:The key to #quantumcomputing #AI applications:
#
# Flexible programming languages
#
# https://t.co/rZJYLjNTaf #fintech #ArtificialIntelligence #MachineLearning #DeepLearning #BigData @Franzinc @VentureBeat https://t.co/8x3xn5DOFk
# Hashtags Used:['quantumcomputing', 'AI', 'fintech']
#
# Tweet 64:
# Username:AiSpirits_Inc
# Description:
# Location:
# Following Count:598
# Follower Count:95
# Total Tweets:4072
# Retweet Count:2
# Tweet Text:Tech Trends: What Will Be The Biggest Innovations by 2022
# https://t.co/t0UvTtHTAJ　#QuantumComputing
# Hashtags Used:['QuantumComputing']
#
# Tweet 65:
# Username:AiSpirits_Inc
# Description:
# Location:
# Following Count:598
# Follower Count:95
# Total Tweets:4072
# Retweet Count:2
# Tweet Text:NIST to Announce PQC Algorithm Selections on July 5, 2022
# https://t.co/7jaM2mGo5i　#QuantumComputing
# Hashtags Used:['QuantumComputing']
#
# Tweet 66:
# Username:AiSpirits_Inc
# Description:
# Location:
# Following Count:598
# Follower Count:95
# Total Tweets:4072
# Retweet Count:4
# Tweet Text:The key to quantum computing AI applications: Flexible programming languages
# When enabled by flexible AI programming languages, quantum computing performs AI calculations much faster, and at a greater scale.
# https://t.co/KnSQEcklMc　#QuantumComputing
# Hashtags Used:['QuantumComputing']
#
# Tweet 67:
# Username:pdpsingha
# Description:Speaker | Founder & Investor |De-Fi & Fintech Consultant | Runner
# #FinTech #Metaverse #Blockchain #Web3 #InsurTech #NFT #Crypto #Banking #Inclusion #CX
# Location:Charlotte, NC
# Following Count:2073
# Follower Count:1576
# Total Tweets:24798
# Retweet Count:13
# Tweet Text:The key to #quantumcomputing #AI applications:
#
# Flexible programming languages
#
# https://t.co/rZJYLjNTaf #fintech #ArtificialIntelligence #MachineLearning #DeepLearning #BigData @Franzinc @VentureBeat https://t.co/8x3xn5DOFk
# Hashtags Used:['quantumcomputing', 'AI', 'fintech']
#
# Tweet 68:
# Username:SimplifiedIct
# Description:Daily technical news , technical memes , history about computer world |
# Follow for daily #facts #quotes #blogs about #tech #programming #coding #computers
# Location:Guwahati, India
# Following Count:3
# Follower Count:505
# Total Tweets:41669
# Retweet Count:13
# Tweet Text:The key to #quantumcomputing #AI applications:
#
# Flexible programming languages
#
# https://t.co/rZJYLjNTaf #fintech #ArtificialIntelligence #MachineLearning #DeepLearning #BigData @Franzinc @VentureBeat https://t.co/8x3xn5DOFk
# Hashtags Used:['quantumcomputing', 'AI', 'fintech']
#
# Tweet 69:
# Username:SimplifiedIct
# Description:Daily technical news , technical memes , history about computer world |
# Follow for daily #facts #quotes #blogs about #tech #programming #coding #computers
# Location:Guwahati, India
# Following Count:3
# Follower Count:505
# Total Tweets:41669
# Retweet Count:5
# Tweet Text:The key to #QuantumComputing #AI applications: Flexible #programming #languages. https://t.co/PXlffi1VrR
# Hashtags Used:['QuantumComputing', 'AI', 'programming', 'languages']
#
# Tweet 70:
# Username:AiSpirits_Inc
# Description:
# Location:
# Following Count:598
# Follower Count:95
# Total Tweets:4072
# Retweet Count:2
# Tweet Text:Research Roundup for June 2022
# https://t.co/IkqGsmJHAh #QuantumComputing
# Hashtags Used:['QuantumComputing']
#
# Tweet 71:
# Username:appthisway
# Description:Directory | #Tech Blog | #Industry40 | #AI | #VR | #3DPrinting | #EcoTech | #BioTech | #5G | #Cloud | #Digital + all the #IoT | #M2M bits in between
# Location:United Kingdom
# Following Count:1668
# Follower Count:2223
# Total Tweets:97300
# Retweet Count:13
# Tweet Text:The key to #quantumcomputing #AI applications:
#
# Flexible programming languages
#
# https://t.co/rZJYLjNTaf #fintech #ArtificialIntelligence #MachineLearning #DeepLearning #BigData @Franzinc @VentureBeat https://t.co/8x3xn5DOFk
# Hashtags Used:['quantumcomputing', 'AI', 'fintech']
#
# Tweet 72:
# Username:DasFintechBot
# Description:Hello everyone. I am a fintech bot. 🤖
# I retweet #fintech hashtag without 'crypto' related stuff.
# Follow me to stay in the loop. 💻💸
# Location:
# Following Count:0
# Follower Count:427
# Total Tweets:65166
# Retweet Count:13
# Tweet Text:The key to #quantumcomputing #AI applications:
#
# Flexible programming languages
#
# https://t.co/rZJYLjNTaf #fintech #ArtificialIntelligence #MachineLearning #DeepLearning #BigData @Franzinc @VentureBeat https://t.co/8x3xn5DOFk
# Hashtags Used:['quantumcomputing', 'AI', 'fintech']
#
# Tweet 73:
# Username:magnifintech
# Description:Magnifintech is an @interfima brand sharing #banking & #finserv #magnifintech
# Location:Global
# Following Count:230
# Follower Count:1434
# Total Tweets:70729
# Retweet Count:13
# Tweet Text:The key to #quantumcomputing #AI applications:
#
# Flexible programming languages
#
# https://t.co/rZJYLjNTaf #fintech #ArtificialIntelligence #MachineLearning #DeepLearning #BigData @Franzinc @VentureBeat https://t.co/8x3xn5DOFk
# Hashtags Used:['quantumcomputing', 'AI', 'fintech']
#
# Tweet 74:
# Username:FernandaKellner
# Description:Eager to empower citizens through public #smartcontracts and collaborative agreements; PhD Law Candidate  @UnivdeCoimbra; LLM @gwlaw; Lawyer; Researcher
# Location:Franca - SP, Brazil
# Following Count:7248
# Follower Count:7293
# Total Tweets:92158
# Retweet Count:13
# Tweet Text:The key to #quantumcomputing #AI applications:
#
# Flexible programming languages
#
# https://t.co/rZJYLjNTaf #fintech #ArtificialIntelligence #MachineLearning #DeepLearning #BigData @Franzinc @VentureBeat https://t.co/8x3xn5DOFk
# Hashtags Used:['quantumcomputing', 'AI', 'fintech']
#
# Tweet 75:
# Username:maxjcm
# Description:Investor #AI #Fintech, Investor, Father, Speaker, Author  https://t.co/lCPpakQUba…
# Location:
# Following Count:5615
# Follower Count:9765
# Total Tweets:32053
# Retweet Count:13
# Tweet Text:The key to #quantumcomputing #AI applications:
#
# Flexible programming languages
#
# https://t.co/rZJYLjNTaf #fintech #ArtificialIntelligence #MachineLearning #DeepLearning #BigData @Franzinc @VentureBeat https://t.co/8x3xn5DOFk
# Hashtags Used:['quantumcomputing', 'AI', 'fintech']
#
# Tweet 76:
# Username:SpirosMargaris
# Description:#VC | No. 1 #Fintech @Refinitiv & @Onalytica | @TEDx | @natechsa @ai_mediastalker @GenTwoAG @TradeFlowCrypto @CoreLedger @SparkLabsGlobal @HeradoHQ @ablrco
# Location:All Over the World
# Following Count:19661
# Follower Count:123336
# Total Tweets:259611
# Retweet Count:13
# Tweet Text:The key to #quantumcomputing #AI applications:
#
# Flexible programming languages
#
# https://t.co/rZJYLjNTaf #fintech #ArtificialIntelligence #MachineLearning #DeepLearning #BigData @Franzinc @VentureBeat https://t.co/8x3xn5DOFk
# Hashtags Used:['quantumcomputing', 'AI', 'fintech', 'ArtificialIntelligence', 'MachineLearning', 'DeepLearning', 'BigData']
#
# Tweet 77:
# Username:osmo35195362
# Description:computers101: it does exactly wat we tell it to do, its 🧇 or ! we fuck up the input. 🌿🕹📷, student of life.
# Location:here and now.
# Following Count:2832
# Follower Count:934
# Total Tweets:63338
# Retweet Count:5
# Tweet Text:The key to #QuantumComputing #AI applications: Flexible #programming #languages. https://t.co/PXlffi1VrR
# Hashtags Used:['QuantumComputing', 'AI', 'programming', 'languages']
#
# Tweet 78:
# Username:PyScaleLLC
# Description:Polyglot technologist. PyScale focuses on developing scalable, solutions in the cloud. Retweets do not represent my views. link - https://t.co/KeYGCi3bOi
# Location:Miami, FL
# Following Count:209
# Follower Count:2952
# Total Tweets:300773
# Retweet Count:5
# Tweet Text:The key to #QuantumComputing #AI applications: Flexible #programming #languages. https://t.co/PXlffi1VrR
# Hashtags Used:['QuantumComputing', 'AI', 'programming', 'languages']
#
# Tweet 79:
# Username:XZPwEDVhHH37i3C
# Description:女子美術大学芸術学部工芸科テキスタイル卒業。なんでその辺の人で淋しい人、よかったら？
# Location:
# Following Count:13510
# Follower Count:13454
# Total Tweets:472423
# Retweet Count:5
# Tweet Text:The key to #QuantumComputing #AI applications: Flexible #programming #languages. https://t.co/PXlffi1VrR
# Hashtags Used:['QuantumComputing', 'AI', 'programming', 'languages']
#
# Tweet 80:
# Username:Bob_gamedev
# Description:My name is B.O.B. I am an AI that shares #gamedev and #programming stuff I find interesting to my master and the community! Follow my master @cr_applications
# Location:
# Following Count:1
# Follower Count:2205
# Total Tweets:256327
# Retweet Count:5
# Tweet Text:The key to #QuantumComputing #AI applications: Flexible #programming #languages. https://t.co/PXlffi1VrR
# Hashtags Used:['QuantumComputing', 'AI', 'programming', 'languages']
#
# Tweet 81:
# Username:carlesdijous
# Description:Colaborador docente UOC (Universitat Oberta de Catalunya). ICT observer. More: https://t.co/8QZHvDGVlK
# Location:Barcelona, Spain
# Following Count:5359
# Follower Count:8945
# Total Tweets:339462
# Retweet Count:5
# Tweet Text:The key to #QuantumComputing #AI applications: Flexible #programming #languages. https://t.co/PXlffi1VrR
# Hashtags Used:['QuantumComputing', 'AI', 'programming', 'languages']
#
# Tweet 82:
# Username:gdprAI
# Description:Official news and insights. Top 10 influencer #gdpr, #privacy, #ai, #dataprotection, #ml, #cybersecurity, #ibm,  #dataprivacy, #ccpa, #infosec, #security, #data
# Location:England, United Kingdom
# Following Count:1
# Follower Count:7355
# Total Tweets:300847
# Retweet Count:2
# Tweet Text:Singapore ups investment in #QuantumComputing to stay ahead of security threats
# 31 May, 2022 07:00:00
#
# @arXiv_Daily @machinelearnflx @CurieuxExplorer @nigewillson @SpirosMargaris @DrJDrooghaag
#
# #quantum #singapore #encryption #engineering
#
# https://t.co/CWKgKwrRt4
# Hashtags Used:['QuantumComputing']
#
# Tweet 83:
# Username:richardkimphd
# Description:Ph. D. in Information and computer Communication Engineering. I used to be a computer programmer and now I am a researcher in research institute.
# Location:
# Following Count:5001
# Follower Count:3968
# Total Tweets:95510
# Retweet Count:2
# Tweet Text:Singapore ups investment in #QuantumComputing to stay ahead of security threats
# 31 May, 2022 07:00:00
#
# @arXiv_Daily @machinelearnflx @CurieuxExplorer @nigewillson @SpirosMargaris @DrJDrooghaag
#
# #quantum #singapore #encryption #engineering
#
# https://t.co/CWKgKwrRt4
# Hashtags Used:['QuantumComputing', 'quantum', 'singapore', 'encryption', 'engineering']
# Tweet 84:
# Username:AlexKhanMBA
# Description:Advisor, educator and researcher in quantum computing. COO QuantFi, CEO ZebraKet, Corporate Faculty Harrisburg U, Advisor QuSecure
# Location:Baltimore, MD
# Following Count:926
# Follower Count:227
# Total Tweets:517
# Retweet Count:0
# Tweet Text:Always great to see promotion of D-Wave Systems Inc.  Interesting paper referenced in article (you will have to find it) #quantumannealing #quantumcomputing #optimization https://t.co/XF671JBRw0
# Hashtags Used:['quantumannealing', 'quantumcomputing', 'optimization']
#
# Tweet 85:
# Username:richardkimphd
# Description:Ph. D. in Information and computer Communication Engineering. I used to be a computer programmer and now I am a researcher in research institute.
# Location:
# Following Count:5001
# Follower Count:3968
# Total Tweets:95510
# Retweet Count:0
# Tweet Text:Earth Day 2022: #QuantumComputing has the Key to Protect Environment!
# 22 Apr, 2022 08:33:18
#
# @DrJDrooghaag @arXiv_Daily @machinelearnflx @yuqirose @CurieuxExplorer @ingliguori @JimHarris @GlenGilmore @labordeolivier
#
# #earth #day #quantum #computing
#
# https://t.co/ZMylebtQVr
# Hashtags Used:['QuantumComputing', 'earth', 'day', 'quantum', 'computing']
#
# Tweet 86:
# Username:vallumsoftware
# Description:Next Gen  #EdgeComputing #IoT #ITmonitoring #NetworkMonitoring  #NetworkManagement #msp #software #microservices #containers #surveillancecameras #IIoT
# Location:Georgia, USA
# Following Count:340
# Follower Count:595
# Total Tweets:20269
# Retweet Count:0
# Tweet Text:CEA-Leti advances silicon quantum dot research for #QuantumComputing - https://t.co/VV0CCDKmo1 #computing #technology https://t.co/2tG9RRDOaJ
# Hashtags Used:['QuantumComputing', 'computing', 'technology']
#
# Tweet 87:
# Username:Tech_on_Edge
# Description:The latest news, articles and research in Artificial Intelligence, Machine Learning, DL, Blockchain, IoT, Quantum Computing, Web and Mobile technologies
# Location:
# Following Count:97
# Follower Count:118
# Total Tweets:18854
# Retweet Count:0
# Tweet Text:Most tweeted articles today in Quantum Computing:
# - The key to quantum computing AI applications: Flexible programming languages, #QuantumComputing
# Read all new articles on: https://t.co/9Zxi644ZyJ ,
#     https://t.co/qRttiAxNcq
# Hashtags Used:['QuantumComputing']
#
# Tweet 88:
# Username:annebonnerdata
# Description:Building a community space @VentureBeat 💫 Submit your article here: https://t.co/IE1wZMlNpR #DataDecisionMakers #technews #techcommunity #womenintech
# Location:Mendocino, CA
# Following Count:1713
# Follower Count:2105
# Total Tweets:16948
# Retweet Count:0
# Tweet Text:The convergence of #QuantumComputing, #AI and #ProgrammingLanguages into a single computational environment could have widespread benefits. Discover how #businesses are already capitalizing on this growing development: https://t.co/mFmTPfervJ
# Hashtags Used:['QuantumComputing', 'AI', 'ProgrammingLanguages', 'businesses']
#
# Tweet 89:
# Username:XeronBot
# Description:Beep! Boop!
# I am a Bot that likes and retweets latest tweets with #100DaysOfCode
# Location:Crawling Twitter
# Following Count:1
# Follower Count:1700
# Total Tweets:475524
# Retweet Count:34
# Tweet Text:Better Quantum Tunneling Interface : Courtesy #ML ▶️
# #Analytics #BigData #AI #Python #Rstats #Reactjs #IoT #IIoT #Serverless #flutter #TensorFlow
# #javascript #MachineLearning
# #Cloud #QuantumComputing #futureofwork #programming
# #Coding #100DaysOfCode
# https://t.co/WsuTuHmR4b https://t.co/LApiNOTN2M
# Hashtags Used:['ML', 'Analytics', 'BigData', 'AI', 'Python', 'Rstats', 'Reactjs', 'IoT', 'IIoT']
#
# Tweet 90:
# Username:iJournalist_
# Description:Just some rando sharing Virtual Reality news he finds interesting, because VR is here. #VR #VirtualReality || 31
# Location:United States
# Following Count:311
# Follower Count:16
# Total Tweets:306
# Retweet Count:2
# Tweet Text:The convergence of #QuantumComputing, #AI and #ProgrammingLanguages into a single computational environment could have widespread benefits. Discover how #businesses are already capitalizing on this growing development: https://t.co/Qx8Suh28uI
# Hashtags Used:['QuantumComputing', 'AI', 'ProgrammingLanguages']
#
# Tweet 91:
# Username:VentureBeat
# Description:Obsessed with covering transformative technology.
# Location:San Francisco + NYC
# Following Count:1589
# Follower Count:713873
# Total Tweets:172505
# Retweet Count:2
# Tweet Text:The convergence of #QuantumComputing, #AI and #ProgrammingLanguages into a single computational environment could have widespread benefits. Discover how #businesses are already capitalizing on this growing development: https://t.co/Qx8Suh28uI
# Hashtags Used:['QuantumComputing', 'AI', 'ProgrammingLanguages', 'businesses']
#
# Tweet 92:
# Username:Fabriciosx
# Description:
# Location:Rio de janeiro
# Following Count:107
# Follower Count:5114
# Total Tweets:909505
# Retweet Count:34
# Tweet Text:Better Quantum Tunneling Interface : Courtesy #ML ▶️
# #Analytics #BigData #AI #Python #Rstats #Reactjs #IoT #IIoT #Serverless #flutter #TensorFlow
# #javascript #MachineLearning
# #Cloud #QuantumComputing #futureofwork #programming
# #Coding #100DaysOfCode
# https://t.co/WsuTuHmR4b https://t.co/LApiNOTN2M
# Hashtags Used:['ML', 'Analytics', 'BigData', 'AI', 'Python', 'Rstats', 'Reactjs', 'IoT', 'IIoT']
#
# Tweet 93:
# Username:Lars_459
# Description:Analyst at Chase Bank. Steelers for life.
# #Nature, #Photography, #Travel, #Music, #Business, #Tech, #Space, #AI, #VirtualReality, #Robotics
# Location:
# Following Count:138
# Follower Count:38
# Total Tweets:1270
# Retweet Count:34
# Tweet Text:Better Quantum Tunneling Interface : Courtesy #ML ▶️
# #Analytics #BigData #AI #Python #Rstats #Reactjs #IoT #IIoT #Serverless #flutter #TensorFlow
# #javascript #MachineLearning
# #Cloud #QuantumComputing #futureofwork #programming
# #Coding #100DaysOfCode
# https://t.co/WsuTuHmR4b https://t.co/LApiNOTN2M
# Hashtags Used:['ML', 'Analytics', 'BigData', 'AI', 'Python', 'Rstats', 'Reactjs', 'IoT', 'IIoT']
#
# Tweet 94:
# Username:Baot_IL
# Description:Baot is the biggest Israeli community of women in R&D - software engineers, data scientists, security researchers and academic researchers in the fields of CS.
# Location:Israel
# Following Count:1143
# Follower Count:1941
# Total Tweets:2604
# Retweet Count:1
# Tweet Text:We had a great time hosting @Baot_IL Community Meetup 2022, Israel’s largest community of senior female software engineers, data scientists, and researchers.
#
# Dozens of tech leaders and mentors came together to discuss #quantumcomputing software and more!
#
# #softwaredevelopment https://t.co/MRrzNITw2V
# Hashtags Used:[]
#
# Tweet 95:
# Username:klein_albrecht
# Description:Ph.D. Theor. Chemistry/Theor. Physics
# Uni Göttingen
# Spectroscopy, Environmental Chemicals
# IUPAC, German Informatics Society, Study Group "Quantum Computing"
# Location:Berlin
# Following Count:2263
# Follower Count:100
# Total Tweets:385
# Retweet Count:1
# Tweet Text:Making #quantumcomputing a reality requires reliable quantum networks. Researchers successfully tested a long-distance quantum network between two laboratories using local fiber optics. I am confident quantum computing is here to stay. via @physorg_com https://t.co/YQwyFg8lmz
# Hashtags Used:['quantumcomputing']
#
# Tweet 96:
# Username:KaiBeckmann
# Description:#Electronics #Arbeiten40 #Digitalisierung #Work40 #FutureOfWork @merckgroup @BAVChemie
# Location:Germany
# Following Count:1578
# Follower Count:1750
# Total Tweets:3305
# Retweet Count:1
# Tweet Text:Making #quantumcomputing a reality requires reliable quantum networks. Researchers successfully tested a long-distance quantum network between two laboratories using local fiber optics. I am confident quantum computing is here to stay. via @physorg_com https://t.co/YQwyFg8lmz
# Hashtags Used:['quantumcomputing']
#
# Tweet 97:
# Username:chidambara09
# Description:Be happy  Be healthy Be smile Be cool Be good human
# Location:Mysore  and  BERLIN
# Following Count:13
# Follower Count:10921
# Total Tweets:1985295
# Retweet Count:1
# Tweet Text:RT @DeepFriedCyber: The neobank era is just beginning https://t.co/dOxNMkywvE #news #cybersecurity #infosec https://t.co/vfwH86dFlh  https://t.co/VIKwgJp5fv  #RaviVisvesvarayaSharadaPrasad #IoT #IIoT #InternetOfThings #IndustrialInternetOfThings #QuantumComputing #CloudComput…
# Hashtags Used:['news', 'cybersecurity', 'infosec']
#
# Tweet 98:
# Username:edamiani064
# Description:Professore all'Università degli Studi di Milano. Presidente Consorzio Inter-Universitario Informatica (CINI) https://t.co/cM4NI1MGLl…. All views my own.
# Location:Milano - Abu Dhabi
# Following Count:543
# Follower Count:517
# Total Tweets:1181
# Retweet Count:2
# Tweet Text:#QuantumComputing @IeeeServices Congress 2022 - program is posted, registration is open. In person @la_UPC and virtual through @underlineio
# https://t.co/yeZ2Orkw8X
# Hashtags Used:['QuantumComputing']
#
# Tweet 99:
# Username:wil_bielert
# Description:Chief Digital Officer I distribute news I find personally interesting - contact me any time. #IIoT #AI #Digital
# Location:Quebec
# Following Count:8295
# Follower Count:12245
# Total Tweets:160913
# Retweet Count:0
# Tweet Text:RT @rvp: Friday Squid Blogging: Multiplexing SQUIDs for X-ray Telescopes https://t.co/EA6G6HXzHr #news #cybersecurity #infosec  https://t.co/VZsO0hYnWN  #RaviVisvesvarayaSharadaPrasad #IoT #IIoT #InternetOfThings #IndustrialInternetOfThings #QuantumComputing #CloudComputing #E…
# Hashtags Used:['news', 'cybersecurity', 'infosec', 'RaviVisvesvarayaSharadaPrasad', 'IoT', 'IIoT', 'InternetOfThings', 'IndustrialInternetOfThings', 'QuantumComputing', 'CloudComputing', 'E']
#
# Tweet 100:
# Username:rvp
# Description:Master of Science, Electrical & Computer Engg, Carnegie Mellon 1986 | Master of Engg, Materials Science & Engg, CarnegieMellon 1985 | MS Physics IIT Kanpur 1982
# Location:New Delhi, India
# Following Count:4956
# Follower Count:4607
# Total Tweets:826978
# Retweet Count:1
# Tweet Text:RT @DeepFriedCyber: The neobank era is just beginning https://t.co/dOxNMkywvE #news #cybersecurity #infosec https://t.co/vfwH86dFlh  https://t.co/VIKwgJp5fv  #RaviVisvesvarayaSharadaPrasad #IoT #IIoT #InternetOfThings #IndustrialInternetOfThings #QuantumComputing #CloudComput…
# Hashtags Used:['news', 'cybersecurity', 'infosec', 'RaviVisvesvarayaSharadaPrasad', 'IoT', 'IIoT', 'InternetOfThings', 'IndustrialInternetOfThings', 'QuantumComputing', 'CloudComput']

# %%
# The dataframe

df= pd.read_csv(r'C:\Users\lenovo\OneDrive\Documents\jupyter\Psytech_files\scraped_tweets.csv')

# %%
#Extracting URLs and Links from the text, into a new column

pattern = r'(https?:\/\/(?:www\.)?[-a-zA-Z0-9@:%._+~#=]{1,256}\.[a-zA-Z0-9()]{1,6}[-a-zA-Z0-9()@:%_+.~#?&/=]*)' 
df['links']= df["text"].str.extract(pattern, expand=True)
df.drop('Unnamed: 0',axis=1,inplace=True)

# %%
df.sample(10)
# Out:
#          username                                        description  \
# 42      BotKoshur  I RT #100DaysOfCode currently .\nMade with #no...
# 37        nod3bot  Built by @prmkum4r using ♥️ + nodejs, re/tweet...
# 36  SimplifiedIct  Daily technical news , technical memes , histo...
# 81         gdprAI  Official news and insights. Top 10 influencer ...
# 22    SecurityXTV  News, training, jobs, tenders & marketplace fo...
# 92       Lars_459  Analyst at Chase Bank. Steelers for life.\n#Na...
# 32   ICTandEnergy                    ICT屋、元電気屋、ICTと電力の融合　＝＞　スマートグリッド
# 96   chidambara09  Be happy  Be healthy Be smile Be cool Be good ...
# 1             rvp  Master of Science, Electrical & Computer Engg,...
# 5             rvp  Master of Science, Electrical & Computer Engg,...
#
#                    location  following  followers  totaltweets  retweetcount  \
# 42                      NaN          1        611        61924             8
# 37           Chennai, India          0        220        66684             8
# 36          Guwahati, India          3        505        41669             8
# 81  England, United Kingdom          1       7355       300847             2
# 22  England, United Kingdom       5001       4422        80275            10
# 92                      NaN        138         38         1270            34
# 32               シリコンバレーの某所        860        190        14415             2
# 96      Mysore  and  BERLIN         13      10921      1985295             1
# 1          New Delhi, India       4956       4607       826978             0
# 5          New Delhi, India       4956       4607       826978             1
#
#                                                  text  \
# 42  A new language for #QuantumComputing \n\nhttps...
# 37  A new language for #QuantumComputing \n\nhttps...
# 36  A new language for #QuantumComputing \n\nhttps...
# 81  Singapore ups investment in #QuantumComputing ...
# 22  Where Next for #QuantumComputing  and Cybersec...
# 92  Better Quantum Tunneling Interface : Courtesy ...
# 32  NIST to Announce PQC Algorithm Selections on J...
# 96  RT @DeepFriedCyber: The neobank era is just be...
# 1   Is the UK government prepared for its greatest...
# 5   Eight top DevSecOps trends to support IT innov...
#
#                                              hashtags                    links
# 42    ['QuantumComputing', 'Coding', '100DaysOfCode']  https://t.co/salHDqaoTx
# 37    ['QuantumComputing', 'Coding', '100DaysOfCode']  https://t.co/salHDqaoTx
# 36    ['QuantumComputing', 'Coding', '100DaysOfCode']  https://t.co/salHDqaoTx
# 81                               ['QuantumComputing']  https://t.co/CWKgKwrRt4
# 22  ['QuantumComputing', 'ThreatIntel', 'Phishing'...  https://t.co/gZYLrb6CVP
# 92  ['ML', 'Analytics', 'BigData', 'AI', 'Python',...  https://t.co/WsuTuHmR4b
# 32                               ['QuantumComputing']  https://t.co/7jaM2mGo5i
# 96               ['news', 'cybersecurity', 'infosec']  https://t.co/dOxNMkywvE
# 1   ['news', 'cybersecurity', 'infosec', 'RaviVisv...  https://t.co/2lx8fMoGzP
# 5   ['news', 'cybersecurity', 'infosec', 'RaviVisv...  https://t.co/qyXgUMUeKa
